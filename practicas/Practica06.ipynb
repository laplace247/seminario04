# %%
#Ejercicio 01 - Nivel Basico
#analizar los datos de ingflacion mesual de peru durante el ultimo año
#crear una grafica de lineas para visualizar el aumento o disminucion de la inflacion

import matplotlib.pyplot as plt

#generar data para el analisis
meses = ['Enero','Febrero','Marzo','Abril','Mayo','Junio','Julio','Agosto','Septiembre','Octubre','Noviembre','Diciembre']
inflacion = [1.2,1.5,2.0,2.3,2.5,2.7,2.8,2.6,2.1,2.7,2.2,2.0]

#crear grafica
plt.plot(meses,inflacion,marker='o',color='blue')
plt.xlabel('Meses')
plt.ylabel('Inflacion')
plt.title('Inflacion mensual de Peru')
plt.grid(True)
plt.xticks(rotation=45)
plt.show()

# %%
#Ejercicio 02
#visualizar el crecimiento del producto bruto interno (PBI) en tres sectores claves del Peru

import matplotlib.pyplot as plt

#datos de crecimeinto del PBI
sectores=['Agricultura','Mineria','Comercio']
pbi=[4.8,3.9,2.4]

#mostrar grafica
plt.bar(sectores,pbi,color=['green','gold','blue'])
plt.xlabel('Sectores')
plt.ylabel('Crecimiento del PBI')
plt.title('Crecimiento del PBI en tres sectores')
plt.show()

# %%
#Ejercicio 01 - Nivel Intermedio
#analizar los datos de ingflacion mesual de peru durante el ultimo año
#crear una grafica de lineas para visualizar el aumento o disminucion
#v2.0
#generar datos aleatorios de inflacion mensual y visualizar la curva de inflacion
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

#generar los datos aleatorios
meses = ['Enero','Febrero','Marzo','Abril','Mayo','Junio','Julio','Agosto','Septiembre','Octubre','Noviembre','Diciembre']
inflacion = np.random.uniform(1.0,5.0,12) #inflacion entre 1% y 5%

#crear la grafica
plt.plot(meses,inflacion,marker='o',color='blue')
plt.xlabel('Meses')
plt.ylabel('Inflacion')
plt.title('Inflacion mensual de Peru - Elementos random')
plt.grid(True)
plt.xticks(rotation=45)

#guardar datos en archivos csv
df = pd.DataFrame({'Meses':meses,'Inflacion':inflacion})
df.to_csv('inflacion_mensual.csv',index=False)
plt.show()

#descargar el archivos csv
from google.colab import files
files.download('inflacion_mensual.csv')

#mostrar los valores por cada mes
print(df)
# Out:
#          Meses  Inflacion
# 0        Enero   2.414692
# 1      Febrero   3.401494
# 2        Marzo   1.659920
# 3        Abril   4.424915
# 4         Mayo   1.188966
# 5        Junio   1.833206
# 6        Julio   3.829305
# 7       Agosto   4.794071
# 8   Septiembre   4.841103
# 9      Octubre   1.174911
# 10   Noviembre   1.264959
# 11   Diciembre   4.036142

# %%
#Ejercicio 02 - Nivel Intermedio
#visualizar el crecimiento del producto bruto interno (PBI) en tres sectores claves del Peru

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

#generar los datos aleatorios de crecimiento del PBI
sectores=['Agricultura','Mineria','Comercio']
pbi=np.random.uniform(0,10,3)

#grafica
plt.bar(sectores,pbi,color=['green','gold','blue'])
plt.xlabel('Sectores')
plt.ylabel('Crecimiento del PBI')
plt.title('Crecimiento del PBI en tres sectores')
plt.show()

#guardar los datos
df = pd.DataFrame({'Sectores':sectores,'PBI':pbi})
df.to_csv('crecimiento_pbi.csv',index=False)

#descargar el archivo csv
from google.colab import files
files.download('crecimiento_pbi.csv')

#mostrar los valores
print(df)
# Out:
#       Sectores       PBI
# 0  Agricultura  2.080290
# 1      Mineria  9.008185
# 2     Comercio  4.182307

# %%
#Ejercicio 03
#distribucion de casos de covid-19 por regiones

import seaborn as sns
import matplotlib.pyplot as plt

#crear los datos
regiones=['Lima','Cusco','Arequipa','Tacna','Piura','Puno']
casos=[25000,12000,35000,1000,10000,5800]

#crear grafica
sns.barplot(x=regiones,y=casos,palette='pastel')
plt.xlabel('Regiones')
plt.ylabel('Casos de Covid-19')
plt.title('Distribucion de casos de COVID-19 por regiones')
plt.show()
# Out:
# <ipython-input-13-4c315d1d03c1>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=regiones,y=casos,palette='pastel')

# %%
#version 2 del Ejercicio 03
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

#generar los datos aleatorios pa los casos de covid
regiones=['Lima','Cusco','Arequipa','Tacna','Piura','Puno']
casos=np.random.randint(900,100000,6)

#crear grafica
sns.barplot(x=regiones,y=casos,palette='coolwarm')
plt.xlabel('Regiones')
plt.ylabel('Casos de Covid-19')
plt.title('Distribucion de casos de covid-19 por regiones')
plt.show()

#crear el archivo csv
df = pd.DataFrame({'Regiones':regiones,'Casos':casos})
df.to_csv('casos_covid.csv',index=False)

#descargar el archivo csv
from google.colab import files
files.download('casos_covid.csv')
# Out:
# <ipython-input-15-d9012e44d973>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=regiones,y=casos,palette='coolwarm')

# %%
#Ejercicio 04
#mostrar segun grafica el desempleo en peru

import matplotlib.pyplot as plt

#generar los datos en los ultimos 6 años
años=[2018,2019,2020,2021,2022,2023]
desempleo=[5.6,6.8,9.5,3.4,7.5,6.5]

#crear la grafica
plt.plot(años,desempleo,marker='o',color='r')
plt.xlabel('Años')
plt.ylabel('Desempleo')
plt.title('Desempleo en Peru')
plt.grid(True)
plt.show()

# %%
#version 2 de Ejercicio 4
#mostrar segun grafica desempleo en peru
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

#generar los datos aleatorios
años=[2018,2019,2020,2021,2022,2023]
desempleo=np.random.uniform(4,20,6) #desempleo de 4% hasta 20%

#crear grafica
plt.plot(años,desempleo,marker='o',color='r')
plt.xlabel('Años')
plt.ylabel('Desempleo')
plt.title('Desempleo en Peru')
plt.grid(True)
plt.show()

#guardar archivo csv
df = pd.DataFrame({'Años':años,'Desempleo':desempleo})
df.to_csv('desempleo_peru.csv',index=False)

#descargar el archivo
from google.colab import files
files.download('desempleo_peru.csv')

# %%
#Ejercicio 05
#Relacion entre ingresos y niveles educativos #GRAFICA de DISPERSION
#NIVEL EDUCATIVO : PRIMARIA,SECUNDARIA,TECNICO,UNIVERSITARIO
#INGRESOS PROMEDIO : 800,1000,1500,1800
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

#generar los datos
data = {'Niveles Educativos':['Primaria','Secundaria','Tecnico','Universitario'],
        'Ingresos Promedio':[800,1000,1500,1800]}
df = pd.DataFrame(data)

#crear grafica
sns.scatterplot(x='Niveles Educativos',y='Ingresos Promedio',data=df)
plt.xlabel('Niveles Educativos')
plt.ylabel('Ingresos Promedio')
plt.title('Relacion entre Ingresos y Niveles Educativos')
plt.show()

# %%
#version 2 de ejercicio 05
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

#generar los datos aleatorios
nivel_educativo=['Primaria','Secundaria','Tecnico','Universitario']
ingresos_promedio=np.random.uniform(100,8000,4) #4 = nro de elementos

#crear grafica
df=pd.DataFrame({'Nivel Educativo':nivel_educativo,'Ingresos Promedio':ingresos_promedio})
sns.scatterplot(x='Nivel Educativo',y='Ingresos Promedio',data=df)
plt.xlabel('Nivel Educativo')
plt.ylabel('Ingresos Promedio')
plt.title('Relacion entre Ingresos y Nivel Educativo')
plt.show()

#guardar archivo csv
df.to_csv('ingresos_nivel_educativo.csv',index=False)

#descargar el archivo
from google.colab import files
files.download('ingresos_nivel_educativo.csv')

# %%
#Ejercicio 06
#Analisis de gastos promedios en transporte publico
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

#generar datos aleatorios de transporte publico
ciudades=['Tacna','Moquegua','Puno','Tumbes','Trujillo']
gastos_promedio=np.random.uniform(25,250,5)
#crear grafica
df=pd.DataFrame({'Ciudades':ciudades,'Gastos Promedio':gastos_promedio})
sns.barplot(x='Ciudades',y='Gastos Promedio',data=df)
plt.xlabel('Ciudades')
plt.ylabel('Gastos Promedio')
plt.title('Analisis de gastos promedios en transporte publico')
plt.show()
#mostrar valores
print(df)

#guardar archivo csv
df.to_csv('gastos_promedio_transporte.csv',index=False)

#descargar el archivo
from google.colab import files
files.download('gastos_promedio_transporte.csv')
# Out:
#    Ciudades  Gastos Promedio
# 0     Tacna        91.059039
# 1  Moquegua        67.441168
# 2      Puno       232.271835
# 3    Tumbes       215.880231
# 4  Trujillo       219.616048

# %%
#Ejercicio Indiv.
#analizar la evolucion de la matricula en senati en las regiones del peru entre los años 2019 y 2023
#usar un grafico de lineas para mostrar la matricula por cada region y grafica de barras para la variacion porcentual
#investiga datos reales o cerca, o sino random que repesenten adecuadamente la realidad de cada region
#-------NOTA---------
#1. crear un grafico de linea que muestra la evolucion de la matricula en al menos 5 regiones del peru
#2. crear un grafico de barras que muestre la variacion porcentual de la matricula entre años 2019 y 2023
#3. culminado el ejercicio  debera expornlo
#4. compartir la conclusion final
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

#generar datos aleatorios de la evolucion de la matricula
años=['2019','2020','2021','2022','2023']
matricula_tacna=[5000,7500,10003,5840,12000]
matricula_cusco=[6000,8490,5300,6700,4900]
matricula_piura=[7580,5470,3950,4390,9050]
matricula_puno=[6740,7560,8040,3940,5390]
matricula_trujillo=[8000,7290,9480,4060,7380]
matricula_junin=[8000,7290,9480,4060,7380]
matricula_moquegua=[8000,7290,9480,4060,7380]
matricula_lambayeque=[8000,7290,9480,4060,7380]
matricula_tumbes=[8000,7290,9480,4060,7380]
matricula_amazonas=[8000,7290,9480,4060,7380]
#crear grafica
plt.plot(años,matricula_tacna,label='Tacna',marker='o',color='blue')
plt.plot(años,matricula_cusco,label='Cusco',marker='o',color='red')
plt.plot(años,matricula_piura,label='Piura',marker='o',color='green')
plt.plot(años,matricula_puno,label='Puno',marker='o',color='pink')
plt.plot(años,matricula_trujillo,label='Trujillo',marker='o',color='brown')
plt.plot(años,matricula_junin,label='Junin',marker='o',color='gold')
plt.plot(años,matricula_moquegua,label='Moquegua',marker='o',color='black')
plt.plot(años,matricula_lambayeque,label='Lamqueyeque',marker='o',color='silver')
plt.plot(años,matricula_tumbes,label='Tumbes',marker='o',color='skyblue')
plt.plot(años,matricula_amazonas,label='Amazonas',marker='o',color='yellow')
plt.title('Evolucion de la matricula en senati por region 2019-2023')
plt.xlabel('Años')
plt.ylabel('Matricula')
plt.legend()
plt.grid(True)
plt.show()


#crear grafica de barras



#mostrar los valores

# %%
#aplicando un random
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

#datos ficticios
años=['2019','2020','2021','2022','2023']
regiones=['Tacna','Cusco','Piura','Puno','Trujillo','Junin','Moquegua','Lambayeque','Tumbes','Amazonas']
#matriculas senati para 10 regiones
matricula_tacna=np.random.randint(30000,60000,5)
matricula_cusco=np.random.randint(90000,100000,5)
matricula_piura=np.random.randint(40000,80000,5)
matricula_puno=np.random.randint(10000,70000,5)
matricula_trujillo=np.random.randint(9000,50000,5)
matricula_junin=np.random.randint(20000,90000,5)
matricula_moquegua=np.random.randint(7000,10000,5)
matricula_lambayeque=np.random.randint(9000,30000,5)
matricula_tumbes=np.random.randint(40000,120000,5)
matricula_amazonas=np.random.randint(20000,80000,5)

#crear dataframe para organizar datos
df=pd.DataFrame({'Años':años,
                 'Tacna':matricula_tacna,
                 'Cusco':matricula_cusco,
                 'Piura':matricula_piura,
                 'Puno':matricula_puno,
                 'Trujillo':matricula_trujillo,
                 'Junin':matricula_junin,
                 'Moquegua':matricula_moquegua,
                 'Lambayeque':matricula_lambayeque,
                 'Tumbes':matricula_tumbes,
                 'Amazonas':matricula_amazonas
                 })
#calcular la variacion porcentual entre 2019 y 2023
variaciones_porcentuales ={
    'Regiones':regiones,
    'Variacion %': [
        ((matricula_tacna[-1]-matricula_tacna[0])/matricula_tacna[0])*100,
        ((matricula_cusco[-1]-matricula_cusco[0])/matricula_cusco[0])*100,
        ((matricula_piura[-1]-matricula_piura[0])/matricula_piura[0])*100,
        ((matricula_puno[-1]-matricula_puno[0])/matricula_puno[0])*100,
        ((matricula_trujillo[-1]-matricula_trujillo[0])/matricula_trujillo[0])*100,
        ((matricula_junin[-1]-matricula_junin[0])/matricula_junin[0])*100,
        ((matricula_moquegua[-1]-matricula_moquegua[0])/matricula_moquegua[0])*100,
        ((matricula_lambayeque[-1]-matricula_lambayeque[0])/matricula_lambayeque[0])*100,
        ((matricula_tumbes[-1]-matricula_tumbes[0])/matricula_tumbes[0])*100,
        ((matricula_amazonas[-1]-matricula_amazonas[0])/matricula_amazonas[0])*100
    ]
}
#crear dataframe cn las variaciones porcentuales
df_variaciones=pd.DataFrame(variaciones_porcentuales)
#crear grafica de barras para la variacion porcentual
plt.figure(figsize=(12,6))
plt.bar(df_variaciones['Regiones'],df_variaciones['Variacion %'],color='skyblue')
plt.title('Variacion porcentual de la matricula en senati por region 2019-2023')
plt.xlabel('Regiones')
plt.ylabel('Variacion %')
plt.xticks(rotation=45)
plt.grid()
plt.show()

#mostrar los valores
print(df)
# Out:
#    Años  Tacna  Cusco  Piura   Puno  Trujillo  Junin  Moquegua  Lambayeque  \
# 0  2019  51701  93541  78145  43284     27299  74772      7115       29777
# 1  2020  48651  99351  62625  47664     29592  58732      7065       10953
# 2  2021  48442  91631  48307  22591     43172  79446      9185       21448
# 3  2022  57156  93188  76527  51306     27284  50524      7113       12349
# 4  2023  30323  96475  60647  53683     36796  73197      7744       16485
#
#    Tumbes  Amazonas
# 0   67536     70595
# 1   68444     58145
# 2   41916     50415
# 3   44003     58126
# 4   75252     59643

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
#DATOS FICTICIOS PARA 10 REGIONES
años=['2019','2020','2021','2022','2023']
regiones=['Tacna','Lima','Cusco','Arequipa','Puno','Piura','Ica','Tumbes','Trujillo','Junin']
#matriculas de senati para las 10 regiones (random)
matricula_tacna = np.random.randint(30000,60000,5)
matricula_lima = np.random.randint(90000,100000,5)
matricula_cusco = np.random.randint(40000,80000,5)
matricula_arequipa = np.random.randint(10000,70000,5)
matricula_puno = np.random.randint(9000,50000,5)
matricula_piura = np.random.randint(20000,90000,5)
matricula_ica = np.random.randint(3000,30000,5)
matricula_tumbes = np.random.randint(1000,10000,5)
matricula_trujillo = np.random.randint(40000,120000,5)
matricula_junin = np.random.randint(20000,80000,5)
#CREAR LA DATAFRAME PARA ORGANIZAR LOS DATOS
df=pd.DataFrame({'Años':años,
                 'Matricula Tacna':matricula_tacna,
                 'Matricula Lima':matricula_lima,
                 'Matricula Cusco':matricula_cusco,
                 'Matricula Arequipa':matricula_arequipa,
                 'Matricula Puno':matricula_puno,
                 'Matricula Piura':matricula_piura,
                 'Matricula Ica':matricula_ica,
                 'Matricula Tumbes':matricula_tumbes,
                 'Matricula Trujillo':matricula_trujillo,
                 'Matricula Junin':matricula_junin
                })
#DESVIACION PORCENTUAL POR CADA REGION
desviacion_porcentuales = {
    'Año':años,
    'Desviacion Tacna %':((matricula_tacna-np.mean(matricula_tacna))/np.mean(matricula_tacna))*100,
    'Desviacion Lima %':((matricula_lima-np.mean(matricula_lima))/np.mean(matricula_lima))*100,
    'Desviacion Cusco %':((matricula_cusco-np.mean(matricula_cusco))/np.mean(matricula_cusco))*100,
    'Desviacion Arequipa %':((matricula_arequipa-np.mean(matricula_arequipa))/np.mean(matricula_arequipa))*100,
    'Desviacion Puno %':((matricula_puno-np.mean(matricula_puno))/np.mean(matricula_puno))*100,
    'Desviacion Piura %':((matricula_piura-np.mean(matricula_piura))/np.mean(matricula_piura))*100,
    'Desviacion Ica %':((matricula_ica-np.mean(matricula_ica))/np.mean(matricula_ica))*100,
    'Desviacion Tumbes %':((matricula_tumbes-np.mean(matricula_tumbes))/np.mean(matricula_tumbes))*100,
    'Desviacion Trujillo %':((matricula_trujillo-np.mean(matricula_trujillo))/np.mean(matricula_trujillo))*100,
    'Desviacion Junin %':((matricula_junin-np.mean(matricula_junin))/np.mean(matricula_junin))*100
}
#creamos la DATAFRAME de las desviaciones porcentuales
df_desviaciones=pd.DataFrame(desviacion_porcentuales)
plt.figure(figsize=(12,8))
width=0.20 # ancho de la barra
x=np.arange(len(años)) #posiciones de las barras

#crear las barras para cada region
bars_tacna = plt.bar(x-2*width,df_desviaciones['Desviacion Tacna %'],width,label='TACNA')
bars_lima =plt.bar(x-width,df_desviaciones['Desviacion Lima %'],width,label='LIMA')
bars_cusco =plt.bar(x,df_desviaciones['Desviacion Cusco %'],width,label='CUSCO')
bars_arequipa =plt.bar(x+width,df_desviaciones['Desviacion Arequipa %'],width,label='AREQUIPA')
bars_puno =plt.bar(x+2*width,df_desviaciones['Desviacion Puno %'],width,label='PUNO')
bars_piura =plt.bar(x+3*width,df_desviaciones['Desviacion Piura %'],width,label='PIURA')
bars_ica =plt.bar(x+4*width,df_desviaciones['Desviacion Ica %'],width,label='ICA')
bars_tumbes =plt.bar(x+5*width,df_desviaciones['Desviacion Tumbes %'],width,label='TUMBES')
bars_trujillo =plt.bar(x+6*width,df_desviaciones['Desviacion Trujillo %'],width,label='TRUJILLO')
bars_junin =plt.bar(x+7*width,df_desviaciones['Desviacion Junin %'],width,label='JUNIN')

#AGREGAR LOS VALORES A LAS BARRAS
for bars in[bars_tacna,bars_lima,bars_cusco,bars_arequipa,bars_puno,bars_piura,bars_ica,bars_tumbes,bars_trujillo,bars_junin]:
  for bar in bars:
    yval=bar.get_height()
    plt.text(bar.get_x()+bar.get_width()/2,yval,f'{yval:.1f}',ha='center',va='bottom',fontsize=6)

'''for i in range(len(años)):
  plt.text(x[i]-2*width,matricula_tacna[i]+500,str(matricula_tacna[i]),ha='center')
  plt.text(x[i]-width,matricula_lima[i]+500,str(matricula_lima[i]),ha='center')
  plt.text(x[i],matricula_cusco[i]+500,str(matricula_cusco[i]),ha='center')
  plt.text(x[i]+width,matricula_arequipa[i]+500,str(matricula_arequipa[i]),ha='center')
  plt.text(x[i]+2*width,matricula_puno[i]+500,str(matricula_puno[i]),ha='center')
  plt.text(x[i]+3*width,matricula_piura[i]+500,str(matricula_piura[i]),ha='center')
  plt.text(x[i]+4*width,matricula_ica[i]+500,str(matricula_ica[i]),ha='center')
  plt.text(x[i]+5*width,matricula_tumbes[i]+500,str(matricula_tumbes[i]),ha='center')
  plt.text(x[i]+6*width,matricula_trujillo[i]+500,str(matricula_trujillo[i]),ha='center')
  plt.text(x[i]+7*width,matricula_junin[i]+500,str(matricula_junin[i]),ha='center')
'''


#configuracion OJOOOOOOOOO
plt.title('Desviacion porcentual de matricula senati por region 2019-2023')
plt.xlabel('Años')
plt.ylabel('Desviacion %')
plt.xticks(x,años)
plt.axhline(0,color='black',linewidth=0.8,linestyle='--')
plt.legend()
plt.grid(axis='y',linestyle='--',alpha=0.7)
plt.show()
